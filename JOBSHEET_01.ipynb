# %% [markdown]
# <a href="https://colab.research.google.com/github/ARL4514/Algoritma-dan-Pemrograman/blob/Jobsheet-1/JOBSHEET_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Praktikum 01: Menghitung Luas Persegi Panjang

# %%
from re import l
p = int(input("Masukkan panjang: "))
l = int(input("Masukan lebar: "))
luas = p * l
print ("Luas persegi panjang =", luas)
# Out:
# Masukkan panjang: 9
# Masukan lebar: 8
# Luas persegi panjang = 72

# %% [markdown]
# Praktikum 02: Menghitung Luas Segitiga

# %%
import math

a = float (input("Masukkan sisi a: "))
b = float (input("Masukkab sisi b: "))
c = float (input("Masukkan sisi c: "))

s = (a + b + c) / 2
luas = math.sqrt (s * (s - a) * (s - b) * (s - c))
print ("Luas segitiga =", luas)
# Out:
# Masukkan sisi a: 5
# Masukkab sisi b: 6
# Masukkan sisi c: 7
# Luas segitiga = 14.696938456699069

# %% [markdown]
# Praktikum 03: Konversi Suhu Celcius ke Fahrenheit

# %%
c = float (input("Masukkan suhu (°C): "))
f = (c * 9/5) + 32
print ("Hasil konversi =", f, "°F")
# Out:
# Masukkan suhu (°C): 28
# Hasil konversi = 82.4 °F

# %% [markdown]
# Praktikum 04: Menghitung Umur Berdasarkan Tahun Lahir

# %%
tahun_lahir = int(input("Masukkan tahun lahir: "))
tahun_sekarang = 2025
umur = tahun_sekarang - tahun_lahir
print("Umur anda =", umur, "tahun")
# Out:
# Masukkan tahun lahir: 2005
# Umur anda = 20 tahun

# %% [markdown]
# Praktikum 05: Menghitung Luas Lingkaran

# %%
import math
r = float (input("Masukkan jari-jari lingkaran: "))
luaa = math.pi * r * r
print ("Luas lingkaran =", luas)
# Out:
# Masukkan jari-jari lingkaran: 7
# Luas lingkaran = 14.696938456699069

# %% [markdown]
# Praktikum 06: Menjumlahkan Tiga Bilangan

# %%
a = int(input("Masukkan bilangan pertama: "))
b = int(input("Masukkan bilangan kedua: "))
c = int(input("Masukkan bilangan ketig: "))
jumlah = a + b + c
print ("Jumlah =", jumlah)
# Out:
# Masukkan bilangan pertama: 1
# Masukkan bilangan kedua: 2
# Masukkan bilangan ketig: 3
# Jumlah = 6

# %% [markdown]
# Penugasan 3. Menghitung Volume Balok

# %%
# Menerima input dari pengguna
panjang = float(input("Masukkan panjang balok: "))
lebar = float(input("Masukkan lebar balok: "))
tinggi = float(input("Masukkan tinggi balok: "))

# Menghitung volume
volume = panjang * lebar * tinggi

# Menampilkan hasil
print(f"Volume balok adalah: {volume:.2f}")
# Menggunakan .2f untuk membulatkan hasil menjadi 2 angka desimal
# Out:
# Masukkan panjang balok: 8
# Masukkan lebar balok: 4
# Masukkan tinggi balok: 6
# Volume balok adalah: 192.00

# %% [markdown]
# Penugasan 4. Konversi Waktu (Detik ke Jam:Menit:Detik)

# %%
# Menerima input total detik dari pengguna
total_detik = int(input("Masukkan total detik: "))

# Menghitung jam, menit, dan detik
jam = total_detik // 3600
sisa_detik = total_detik % 3600
menit = sisa_detik // 60
detik = sisa_detik % 60

# Menampilkan hasil
print(f"Konversi waktu: {jam} jam, {menit} menit, {detik} detik.")
# Out:
# Masukkan total detik: 7200
# Konversi waktu: 2 jam, 0 menit, 0 detik.

# %% [markdown]
# Penugasan 5. Rata-rata Nilai Tiga Mata Kuliah

# %%
# Menerima input tiga nilai dari pengguna
nilai1 = float(input("Masukkan nilai mata kuliah 1: "))
nilai2 = float(input("Masukkan nilai mata kuliah 2: "))
nilai3 = float(input("Masukkan nilai mata kuliah 3: "))

# Menghitung rata-rata
rata_rata = (nilai1 + nilai2 + nilai3) / 3

# Menentukan kelulusan
if rata_rata >= 60:
    status = "Lulus"
else:
    status = "Tidak Lulus"

# Menampilkan hasil
print(f"Rata-rata nilai: {rata_rata:.2f}")
print(f"Status: {status}")
# Out:
# Masukkan nilai mata kuliah 1: 4
# Masukkan nilai mata kuliah 2: 4
# Masukkan nilai mata kuliah 3: 3
# Rata-rata nilai: 3.67
# Status: Tidak Lulus

# %% [markdown]
# Penugasan 6. Menghitung Diskon Belanja

# %%
# Menerima input total belanja dari pengguna
total_belanja = float(input("Masukkan total belanja: "))

# Menentukan diskon berdasarkan kondisi
if total_belanja >= 500000:
    diskon = 0.20
elif total_belanja >= 250000:
    diskon = 0.10
else:
    diskon = 0.0

# Menghitung total bayar setelah diskon
total_bayar = total_belanja - (total_belanja * diskon)

# Menampilkan hasil
print(f"Total belanja: Rp{total_belanja:,.2f}")
print(f"Diskon yang didapat: {diskon * 100:.0f}%")
print(f"Total yang harus dibayar: Rp{total_bayar:,.2f}")
# Out:
# Masukkan total belanja: 650000
# Total belanja: Rp650,000.00
# Diskon yang didapat: 20%
# Total yang harus dibayar: Rp520,000.00
