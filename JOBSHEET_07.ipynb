# %% [markdown]
# <a href="https://colab.research.google.com/github/ARL4514/Algoritma-dan-Pemrograman/blob/Jobsheet-01/JOBSHEET_07.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Praktikum 01 - Tuple: Data Tetap yang Tidak Bisa Diubah

# %%
koordinat = (7.05, 110.44)
print("Lintang:", koordinat[0])
print("Bujur:", koordinat[1])
# Out:
# Lintang: 7.05
# Bujur: 110.44

# %% [markdown]
# Praktikum 02 - Dictionary Dasar: Menyimpan Data Mahasiswa

# %%
mahasiswa = {
    "NIM": "20251001",
    "Nama": "Andi",
    "Prodi": "TRK"
}

print("NIM:", mahasiswa["NIM"])
print("Nama:", mahasiswa["Nama"])
print("Prodi:", mahasiswa["Prodi"])
# Out:
# NIM: 20251001
# Nama: Andi
# Prodi: TRK

# %% [markdown]
# Praktikum 03 - Operasi pada Dictionary

# %%
mahasiswa = {
    "NIM": "20251001",
    "Nama": "Andi",
    "Prodi": "TRK"
}

mahasiswa["Umur"] = 20 # menambah data
mahasiswa["Prodi"] = "Teknik Komputer" # memperbarui data
del mahasiswa["Umur"] # menghapus data

print(mahasiswa)
# Out:
# {'NIM': '20251001', 'Nama': 'Andi', 'Prodi': 'Teknik Komputer'}

# %% [markdown]
# Praktikum 04 - Set dan Operasi Himpunan

# %%
A = {1, 2, 3, 4}
B = {3, 4, 5, 6}

print("Union:", A | B)
print("Intersection:", A & B)
print("Difference:", A - B)
# Out:
# Union: {1, 2, 3, 4, 5, 6}
# Intersection: {3, 4}
# Difference: {1, 2}

# %% [markdown]
# Praktikum 05 - Studi Kasus: Data Mahasiswa dan Mata Kuliah

# %%
mhs1 = {"Algoritma", "Matematika", "Bahasa Inggris"}
mhs2 = {"Algoritma", "Basis Data", "Matematika"}

print("Mata kuliah Mhs1:", mhs1)
print("Mata kuliah Mhs2:", mhs2)
print("Mata kuliah yang sama:", mhs1 & mhs2)
# Out:
# Mata kuliah Mhs1: {'Matematika', 'Bahasa Inggris', 'Algoritma'}
# Mata kuliah Mhs2: {'Matematika', 'Basis Data', 'Algoritma'}
# Mata kuliah yang sama: {'Matematika', 'Algoritma'}

# %% [markdown]
# Praktikum 06 - Studi Kasus Dictionary: Daftar Nilai Mahasiswa

# %%
nilai_mahasiswa = {
    "Andi": 80,
    "Budi": 75,
    "Cici": 90
}

for nama, nilai in nilai_mahasiswa.items():
  print(f"{nama}: {nilai}")

rata = sum(nilai_mahasiswa.values()) / len(nilai_mahasiswa)
print(f"Rata-rata nilai: {rata:.2f}")
# Out:
# Andi: 80
# Budi: 75
# Cici: 90
# Rata-rata nilai: 81.67

# %% [markdown]
# PENUGASAN

# %% [markdown]
# 3. Tuple Sederhana

# %%
data_mahasiswa = ("Budi Santoso", 20, "Teknik Informatika")

nama = data_mahasiswa[0]
umur = data_mahasiswa[1]
prodi = data_mahasiswa[2]

print(f"Nama: {nama} (index 0)")
print(f"Umur: {umur} tahun (Index 1)")
print(f"Program Studi: {prodi} (Index -1)")
# Out:
# Nama: Budi Santoso (index 0)
# Umur: 20 tahun (Index 1)
# Program Studi: Teknik Informatika (Index -1)

# %% [markdown]
# 4. Tuple Tidak Bisa Diubah

# %%
#Tuple Tidak Bisa Diubah
data = (1, 2, 3)
# data[1] = 9 # This line causes an error because tuples are immutable
print(data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-4009390961.py in <cell line: 0>()
#       3 data = (1, 2, 3)
#       4
# ----> 5 data[1] = 9
#       6
#       7 print(data)
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# 5. Dictionary Dasar

# %%
buku = {
    "Judul": "Algoritma",
    "Penulis": "Munir",
    "Tahun": 2021
}

print(f"Buku: {buku}")

print("-" * 30)

judul = buku["Judul"]
penulis = buku["Penulis"]
tahun = buku["Tahun"]

for key, value in buku.items():
    print(f"{key}: {value}")
# Out:
# Buku: {'Judul': 'Algoritma', 'Penulis': 'Munir', 'Tahun': 2021}
# ------------------------------
# Judul: Algoritma
# Penulis: Munir
# Tahun: 2021

# %% [markdown]
# 6. Operasi Dictionary

# %%
Dosen = {
    "NIP": "12345",
    "Nama": "Budi",
    "Prodi": "TRK"
}

Dosen["Umur"] = 40 # menambah data
Dosen["Prodi"] = "Teknik Komputer" # memperbarui data
del Dosen["Umur"] # menghapus data

print(Dosen)
# Out:
# {'NIP': '12345', 'Nama': 'Budi', 'Prodi': 'Teknik Komputer'}

# %% [markdown]
# 7. Set dan Himpunan

# %%
A = {"Matematika", "Algoritma", "Bahasa Inggris"}
B = {"Algoritma", "Basis Data", "Matematika"}

print("Union:", A | B)
print("Intersection:", A & B)
print("Difference:", A - B)
print("Difference:", B - A)
# Out:
# Union: {'Matematika', 'Basis Data', 'Bahasa Inggris', 'Algoritma'}
# Intersection: {'Matematika', 'Algoritma'}
# Difference: {'Bahasa Inggris'}
# Difference: {'Basis Data'}

# %% [markdown]
# 8. Studi Kasus Dictionary

# %%
nilai_mahasiswa = {
    "Andi": 85,
    "Budi": 90,
    "Cici": 78
}

for nama, nilai in nilai_mahasiswa.items():
  print(f"{nama}: {nilai}")

rata = sum(nilai_mahasiswa.values()) / len(nilai_mahasiswa)
print(f"Rata-rata nilai: {rata:.2f}")
# Out:
# Andi: 85
# Budi: 90
# Cici: 78
# Rata-rata nilai: 84.33

# %% [markdown]
# 9. Studi Kasus Set - Klub Mahasiswa

# %%
A = {"Andi", "Budi", "Cici"}
B = {"Cici", "Deni", "Eka"}

print("Union:", A | B)
print("Intersection:", A & B)
print("Difference:", A - B)
# Out:
# Union: {'Cici', 'Eka', 'Andi', 'Budi', 'Deni'}
# Intersection: {'Cici'}
# Difference: {'Budi', 'Andi'}
