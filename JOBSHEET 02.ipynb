# %% [markdown]
# <a href="https://colab.research.google.com/github/ARL4514/Algoritma-dan-Pemrograman/blob/Jobsheet-01/Jobsheet_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Praktikum 01 - Pengenalan Variabel dan Tipe Data

# %%
# Integer
umur = 20
print("Umur:", umur, "→", type(umur))

# Float
tinggi =170.5
print("Tinggi:", tinggi, "→", type(tinggi))

# String
nama = "Bayu"
print("Nama:", nama, "→", type(nama))

# Boolean
is_mahasiswa = True
print("Status Mahasiswa:", is_mahasiswa, "→", type(is_mahasiswa))

# List
nilai = [95, 95, 97]
print("Nilai:", nilai, "→", type(nilai))

# Tuple
koordinat = (10,20)
print("Koordinat:", koordinat, "→", type(koordinat))

# Dictionary
mahasiswa = {"nama": "Bayu", "umur": "20", "prodi": "TRK"}
print("Data Mahasiswa:", mahasiswa, "→", type(mahasiswa))

# Set
hobi = {"membaca", "olahraga", "musik"}
print("Hobi:", hobi, "→", type(hobi))
# Out:
# Umur: 20 → <class 'int'>
# Tinggi: 170.5 → <class 'float'>
# Nama: Bayu → <class 'str'>
# Status Mahasiswa: True → <class 'bool'>
# Nilai: [95, 95, 97] → <class 'list'>
# Koordinat: (10, 20) → <class 'tuple'>
# Data Mahasiswa: {'nama': 'Bayu', 'umur': '20', 'prodi': 'TRK'} → <class 'dict'>
# Hobi: {'olahraga', 'membaca', 'musik'} → <class 'set'>

# %%
# Float
tinggi = 170.5
print("Tinggi:", tinggi, "→", type(tinggi))
# Out:
# Tinggi: 170.5 → <class 'float'>

# %%
# String
nama = "Bayu"
print("Nama:", nama, "→", type(nama))
# Out:
# Nama: Bayu → <class 'str'>

# %%
# Boolean
is_mahasiswa = True
print("Status Mahasiswa:", is_mahasiswa, "→", type(is_mahasiswa))
# Out:
# Status Mahasiswa: True → <class 'bool'>

# %%
# List
nilai = [95, 95, 97]
print("Nilai:", nilai, "→", type(nilai))
# Out:
# Nilai: [95, 95, 97] → <class 'list'>

# %%
# Tuple
koordinat = (10,20)
print("Koordinat:", koordinat, "→", type(koordinat))
# Out:
# Koordinat: (10, 20) → <class 'tuple'>

# %%
# Dictionary
mahasiswa = {"nama": "Bayu", "umur": "20", "prodi": "TRK"}
print("Data Mahasiswa:", mahasiswa, "→", type(mahasiswa))
# Out:
# Data Mahasiswa: {'nama': 'Bayu', 'umur': '20', 'prodi': 'TRK'} → <class 'dict'>

# %%
# Set
hobi = {"membaca", "olahraga", "musik"}
print("Hobi:", hobi, "→", type(hobi))
# Out:
# Hobi: {'olahraga', 'musik', 'membaca'} → <class 'set'>

# %% [markdown]
# Praktikum 02 - Input dan Output Dasar (variasi format)

# %%
# Input Stirng
nama = input("Masukkan nama anda: ")

# Input integer
umur = int(input("Masukkan umur anda: "))

# Input float
tinggi = float(input("Masukkan tinggi badan (cm): "))

# Output standar
print("Halo,", nama, "umur anda:", umur, "tahun, tinggi:", tinggi, "cm" )

# Output dengan format()
print("Halo, {0}, umur anda {1} tahun, tinggi {2} cm".format(nama, umur, tinggi))

# Output dengan f-string
print(f"Halo {nama}, umur anda {umur} tahun, tinggi {tinggi} cm")
# Out:
# Masukkan nama anda: Bayu
# Masukkan umur anda: 20
# Masukkan tinggi badan (cm): 170.5
# Halo, Bayu umur anda: 20 tahun, tinggi: 170.5 cm
# Halo, Bayu, umur anda 20 tahun, tinggi 170.5 cm
# Halo Bayu, umur anda 20 tahun, tinggi 170.5 cm

# %%
# Input integer
umur = int(input("Masukkan umur anda: "))
# Out:
# Masukkan umur anda: 20

# %%
# Input float
tinggi = float(input("Masukkan tinggi badan (cm): "))
# Out:
# Masukkan tinggi badan (cm): 170.5

# %%
# Output standar
print("Halo,", nama, "umur anda:", umur, "tahun, tinggi:", tinggi, "cm" )
# Out:
# Halo, Bayu umur anda: 20 tahun, tinggi: 170.5 cm

# %%
# Output dengan format()
print("Halo, {0}, umur anda {1} tahun, tinggi {2} cm".format(nama, umur, tinggi))
# Out:
# Halo, Bayu, umur anda 20 tahun, tinggi 170.5 cm

# %%
# Output dengan f-string
print(f"Halo {nama}, umur anda {umur} tahun, tinggi {tinggi} cm")
# Out:
# Halo Bayu, umur anda 20 tahun, tinggi 170.5 cm

# %% [markdown]
# Praktikum 03 - Operator Aritmatika

# %%
a = 15
b = 4

print("a + b =", a + b)
print("a - b =", a - b)
print("a * b =", a * b)
print("a / b =", a / b)
print("a // b =", a // b)
print("a % b =", a % b)
print("a ** b =", a ** b)
# Out:
# a + b = 19
# a - b = 11
# a * b = 60
# a / b = 3.75
# a // b = 3
# a % b = 3
# a ** b = 50625

# %% [markdown]
# Praktikum 04 - Operator Relasional

# %%
x = 10
y = 20

print("x == y :", x == y)
print("x != y :", x != y)
print("x < y :", x < y)
print("x > y :", x > y)
print("x <= y :", x <= y)
print("x >= y :", x >= y)

# Dalam kehidupan nyata, operator relasional bisa dipakai untuk mengecek apakah nilai ujian > 60, atau apakah kehadiran mahasiswa memenuhi batas minimal
# Out:
# x == y : False
# x != y : True
# x < y : True
# x > y : False
# x <= y : True
# x >= y : False

# %% [markdown]
# Praktikum 05 - Operator Logika (dasar + studi kasus kelulusan)

# %%
# Operator logika dasar
a = True
b = False

print("a and b =", a and b)
print("a or b =", a or b)
print("not a =", not a)

# Studi kasus nyata: kelulusan
nilai = int(input("Masukkan nilai ujian: "))
hadir = int(input("Masukkan jumlah kehadiran: "))

lulus_nilai = nilai >= 60
lulus_hadir = hadir >= 12 # dari 16 pertemuan

if lulus_nilai and lulus_hadir:
  print("Status: LULUS")
else:
  print("Status: TIDAK LULUS")
# Out:
# a and b = False
# a or b = True
# not a = False
# Masukkan nilai ujian: 98
# Masukkan jumlah kehadiran: 12
# Status: LULUS

# %% [markdown]
# Praktikum 06 - Program Kasir Sederhana

# %%
barang = input("Masukkan nama barang: ")
harga = float(input("Masukkan harga barang: "))
jumlah = int (input("Masukkan jumlah barang: "))

total = harga * jumlah

# Aturan diskon
if total >= 500000:
  diskon = 0.2
elif total >= 250000:
  diskon = 0.1
else:
  diskon = 0

potongan = total * diskon
bayar = total - potongan

print("\n===== Struk Belanja =====")
print(f"Barang: {barang}")
print(f"Jumlah: {jumlah}")
print(f"Total: Rp {total}")
print(f"Diskon: {diskon * 100}%")
print(f"Bayar: Rp {bayar}")
# Out:
# Masukkan nama barang: motor
# Masukkan harga barang: 30000000
# Masukkan jumlah barang: 2
#
# ===== Struk Belanja =====
# Barang: motor
# Jumlah: 2
# Total: Rp 60000000.0
# Diskon: 20.0%
# Bayar: Rp 48000000.0

# %% [markdown]
# PENUGASAN

# %% [markdown]
# 3. Identitas Mahasiswa

# %%
nama = input("Masukkan nama Anda: ")
umur = int(input("Masukkan umur Anda: "))
tinggi = float(input("Masukkan tinggi badan (cm): "))
status_aktif = bool(int(input("Apakah Anda mahasiswa aktif? (1 = Ya, 0 = Tidak): ")))

print("\n===== Data Mahasiswa =====")
print(f"Nama           : {nama}")
print(f"Umur           : {umur} tahun")
print(f"Tinggi Badan   : {tinggi} cm")
print(f"Status Aktif   : {status_aktif}")
# Out:
# Masukkan nama Anda: Bayu
# Masukkan umur Anda: 20
# Masukkan tinggi badan (cm): 170.5
# Apakah Anda mahasiswa aktif? (1 = Ya, 0 = Tidak): 1
#
# ===== Data Mahasiswa =====
# Nama           : Bayu
# Umur           : 20 tahun
# Tinggi Badan   : 170.5 cm
# Status Aktif   : True

# %% [markdown]
# 4. Operasi Aritmatika

# %%
bil1 = int(input("Masukkan bilangan pertama: "))
bil2 = int(input("Masukkan bilangan kedua: "))

print("\n===== Hasil Operasi Aritmatika =====")
print(f"Penjumlahan (+)  : {bil1 + bil2}")
print(f"Pengurangan (-)  : {bil1 - bil2}")
print(f"Perkalian (×)    : {bil1 * bil2}")
print(f"Pembagian (/)    : {bil1 / bil2}")
print(f"Sisa Bagi (%)    : {bil1 % bil2}")
print(f"Pangkat (**)     : {bil1 ** bil2}")
# Out:
# Masukkan bilangan pertama: 20
# Masukkan bilangan kedua: 6
#
# ===== Hasil Operasi Aritmatika =====
# Penjumlahan (+)  : 26
# Pengurangan (-)  : 14
# Perkalian (×)    : 120
# Pembagian (/)    : 3.3333333333333335
# Sisa Bagi (%)    : 2
# Pangkat (**)     : 64000000

# %% [markdown]
# 5. Konversi Nilai

# %%
nilai = float(input("Masukkan nilai desimal Anda: "))

print("\n===== Hasil Konversi Nilai =====")
print(f"Nilai dalam bentuk integer : {int(nilai)}")
print(f"Nilai dalam bentuk string  : {str(nilai)}")
print(f"Nilai dibulatkan 2 digit   : {round(nilai, 2)}")
# Out:
# Masukkan nilai desimal Anda: 80.5
#
# ===== Hasil Konversi Nilai =====
# Nilai dalam bentuk integer : 80
# Nilai dalam bentuk string  : 80.5
# Nilai dibulatkan 2 digit   : 80.5

# %% [markdown]
# 6. Operator Relasional

# %%
bil1 = int(input("Masukkan bilangan pertama: "))
bil2 = int(input("Masukkan bilangan kedua: "))

print("\n===== Hasil Perbandingan =====")
print(f"{bil1} == {bil2} : {bil1 == bil2}")
print(f"{bil1} != {bil2} : {bil1 != bil2}")
print(f"{bil1} > {bil2}  : {bil1 > bil2}")
print(f"{bil1} < {bil2}  : {bil1 < bil2}")
print(f"{bil1} >= {bil2} : {bil1 >= bil2}")
print(f"{bil1} <= {bil2} : {bil1 <= bil2}")
# Out:
# Masukkan bilangan pertama: 35
# Masukkan bilangan kedua: 25
#
# ===== Hasil Perbandingan =====
# 35 == 25 : False
# 35 != 25 : True
# 35 > 25  : True
# 35 < 25  : False
# 35 >= 25 : True
# 35 <= 25 : False
