# %% [markdown]
# <a href="https://colab.research.google.com/github/ARL4514/Algoritma-dan-Pemrograman/blob/Jobsheet-01/JOBSHEET_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Praktikum 01 - If sederhana

# %%
nilai = int(input("Masukkan nilai ujian: "))
if nilai >= 60:
  print("Anda LULUS")
# Out:
# Masukkan nilai ujian: 70
# Anda LULUS

# %% [markdown]
# Praktikum 02 - If Else

# %%
nilai = int(input("Masukkan nilai ujian: "))
if nilai >= 60:
  print("Anda LULUS")
else:
  print("Anda TIDAK LULUS")
# Out:
# Masukkan nilai ujian: 50
# Anda TIDAK LULUS

# %% [markdown]
# Praktikum 03 - If Elif Else

# %%
nilai = int(input("Masukkan nilai akhir: "))

if nilai >= 85:
  grade = "A"
elif nilai >= 70:
  grade = "B"
elif nilai  >= 55:
  grade = "C"
elif nilai >= 40:
  grade = "D"
else:
  grade = "E"

print(f"Nilai Anda {nilai}, maka grade Anda = {grade}")
# Out:
# Masukkan nilai akhir: 78
# Nilai Anda 78, maka grade Anda = B

# %% [markdown]
# Praktikum 04 - Nested If

# %% [markdown]
# Nested If (Beasiswa)

# %%
ipk = float(input("Masukkan IPK: "))
sks = int (input("Masukkan jumlah SKS: "))

if ipk >= 3.0:
  if sks >= 18:
    print("Anda LAYAK mendaptakan beasiswa")
  else:
    print("IPK memenuhi, tapi SKS kurang")
else:
  print("Anda TIDAK layak mendapatkan beasiswa")
# Out:
# Masukkan IPK: 3.2
# Masukkan jumlah SKS: 20
# Anda LAYAK mendaptakan beasiswa

# %% [markdown]
# Nested If (Beasiswa, gagal SKS)

# %%
ipk = float(input("Masukkan IPK: "))
sks = int (input("Masukkan jumlah SKS: "))

if ipk >= 3.0:
  if sks >= 18:
    print("Anda LAYAK mendaptakan beasiswa")
  else:
    print("IPK memenuhi, tapi SKS kurang")
else:
  print("Anda TIDAK layak mendapatkan beasiswa")
# Out:
# Masukkan IPK: 3.2
# Masukkan jumlah SKS: 16
# IPK memenuhi, tapi SKS kurang

# %% [markdown]
# Nested If (Beasiswa, gagal IPK)

# %%
ipk = float(input("Masukkan IPK: "))
sks = int (input("Masukkan jumlah SKS: "))

if ipk >= 3.0:
  if sks >= 18:
    print("Anda LAYAK mendaptakan beasiswa")
  else:
    print("IPK memenuhi, tapi SKS kurang")
else:
  print("Anda TIDAK layak mendapatkan beasiswa")
# Out:
# Masukkan IPK: 2.8
# Masukkan jumlah SKS: 20
# Anda TIDAK layak mendapatkan beasiswa

# %% [markdown]
# Praktikum 05 - Match Case

# %% [markdown]
# Match-Case

# %%
menu = int(input("Pilih menu (1-3): "))

match menu:
  case 1:
    print("Anda memilih Nasi Goreng")
  case 2:
    print("Anda memilih Mie Ayam")
  case 3:
    print("Anda memilih Soto Ayam")
  case _:
    print("Menu tidak tersedia")
# Out:
# Pilih menu (1-3): 2
# Anda memilih Mie Ayam

# %% [markdown]
# Match-Case (salah input)

# %%
menu = int(input("Pilih menu (1-3): "))

match menu:
  case 1:
    print("Anda memilih Nasi Goreng")
  case 2:
    print("Anda memilih Mie Ayam")
  case 3:
    print("Anda memilih Soto Ayam")
  case _:
    print("Menu tidak tersedia")
# Out:
# Pilih menu (1-3): 9
# Menu tidak tersedia

# %% [markdown]
# Praktikum 06 - Studi Kasus: Program Kasir

# %% [markdown]
# Program Kasir

# %%
barang = input("Masukkan nama barang: ")
harga = float(input("Masukkan harga barang: "))
jumlah = int (input("Masukkan jumlah barang: "))

total = harga * jumlah

# Aturan diskon
if total >= 500000:
  diskon = 0.2
elif total >= 250000:
  diskon = 0.1
else:
  diskon = 0

bayar = total - (total * diskon)

print("\n===== Struk Belanja =====")
print(f"Barang: {barang}")
print(f"Jumlah: {jumlah}")
print(f"Total: Rp {total}")
print(f"Diskon: {diskon * 100}%")
print(f"Bayar: Rp {bayar}")
# Out:
# Masukkan nama barang: Buku
# Masukkan harga barang: 60000
# Masukkan jumlah barang: 5
#
# ===== Struk Belanja =====
# Barang: Buku
# Jumlah: 5
# Total: Rp 300000.0
# Diskon: 10.0%
# Bayar: Rp 270000.0

# %% [markdown]
# Program Kasir (diskon 20%)

# %%
barang = input("Masukkan nama barang: ")
harga = float(input("Masukkan harga barang: "))
jumlah = int (input("Masukkan jumlah barang: "))

total = harga * jumlah

# Aturan diskon
if total >= 500000:
  diskon = 0.2
elif total >= 250000:
  diskon = 0.1
else:
  diskon = 0

bayar = total - (total * diskon)

print("\n===== Struk Belanja =====")
print(f"Barang: {barang}")
print(f"Jumlah: {jumlah}")
print(f"Total: Rp {total}")
print(f"Diskon: {diskon * 100}%")
print(f"Bayar: Rp {bayar}")
# Out:
# Masukkan nama barang: Tas
# Masukkan harga barang: 200000
# Masukkan jumlah barang: 3
#
# ===== Struk Belanja =====
# Barang: Tas
# Jumlah: 3
# Total: Rp 600000.0
# Diskon: 20.0%
# Bayar: Rp 480000.0

# %% [markdown]
# Program Kasir (tanpa diskon)

# %%
barang = input("Masukkan nama barang: ")
harga = float(input("Masukkan harga barang: "))
jumlah = int (input("Masukkan jumlah barang: "))

total = harga * jumlah

# Aturan diskon
if total >= 500000:
  diskon = 0.2
elif total >= 250000:
  diskon = 0.1
else:
  diskon = 0

bayar = total - (total * diskon)

print("\n===== Struk Belanja =====")
print(f"Barang: {barang}")
print(f"Jumlah: {jumlah}")
print(f"Total: Rp {total}")
print(f"Diskon: {diskon * 100}%")
print(f"Bayar: Rp {bayar}")
# Out:
# Masukkan nama barang: Pulpen
# Masukkan harga barang: 5000
# Masukkan jumlah barang: 10
#
# ===== Struk Belanja =====
# Barang: Pulpen
# Jumlah: 10
# Total: Rp 50000.0
# Diskon: 0%
# Bayar: Rp 50000.0

# %% [markdown]
# PENUGASAN

# %% [markdown]
# 3. Cek bilangan positif/negatif/nol

# %% [markdown]
# Bilangan Positif

# %%
bil = int(input("Masukkan sebuah bilangan: "))

if bil > 0:
    print("Bilangan positif")
elif bil < 0:
    print("Bilangan negatif")
else:
    print("Bilangan nol")
# Out:
# Masukkan sebuah bilangan: 10
# Bilangan positif

# %% [markdown]
# Bilangan Negatif

# %%
bil = int(input("Masukkan sebuah bilangan: "))

if bil > 0:
    print("Bilangan positif")
elif bil < 0:
    print("Bilangan negatif")
else:
    print("Bilangan nol")
# Out:
# Masukkan sebuah bilangan: -24
# Bilangan negatif

# %% [markdown]
# Bilangan Nol

# %%
bil = int(input("Masukkan sebuah bilangan: "))

if bil > 0:
    print("Bilangan positif")
elif bil < 0:
    print("Bilangan negatif")
else:
    print("Bilangan nol")
# Out:
# Masukkan sebuah bilangan: 0
# Bilangan nol

# %% [markdown]
# 4. Menentukan Kategori Usia

# %% [markdown]
# Balita

# %%
umur = int(input("Masukkan umur Anda: "))

if umur < 5:
    kategori = "Balita"
elif umur <= 11:
    kategori = "Anak-anak"
elif umur <= 17:
    kategori = "Remaja"
elif umur <= 59:
    kategori = "Dewasa"
else:
    kategori = "Lansia"

print(f"Kategori usia Anda adalah: {kategori}")
# Out:
# Masukkan umur Anda: 3
# Kategori usia Anda adalah: Balita

# %% [markdown]
# Anak-anak

# %%
umur = int(input("Masukkan umur Anda: "))

if umur < 5:
    kategori = "Balita"
elif umur <= 11:
    kategori = "Anak-anak"
elif umur <= 17:
    kategori = "Remaja"
elif umur <= 59:
    kategori = "Dewasa"
else:
    kategori = "Lansia"

print(f"Kategori usia Anda adalah: {kategori}")
# Out:
# Masukkan umur Anda: 8
# Kategori usia Anda adalah: Anak-anak

# %% [markdown]
# Remaja

# %%
umur = int(input("Masukkan umur Anda: "))

if umur < 5:
    kategori = "Balita"
elif umur <= 11:
    kategori = "Anak-anak"
elif umur <= 17:
    kategori = "Remaja"
elif umur <= 59:
    kategori = "Dewasa"
else:
    kategori = "Lansia"

print(f"Kategori usia Anda adalah: {kategori}")
# Out:
# Masukkan umur Anda: 15
# Kategori usia Anda adalah: Remaja

# %% [markdown]
# Dewasa

# %%
umur = int(input("Masukkan umur Anda: "))

if umur < 5:
    kategori = "Balita"
elif umur <= 11:
    kategori = "Anak-anak"
elif umur <= 17:
    kategori = "Remaja"
elif umur <= 59:
    kategori = "Dewasa"
else:
    kategori = "Lansia"

print(f"Kategori usia Anda adalah: {kategori}")
# Out:
# Masukkan umur Anda: 20
# Kategori usia Anda adalah: Dewasa

# %% [markdown]
# Lansia

# %%
umur = int(input("Masukkan umur Anda: "))

if umur < 5:
    kategori = "Balita"
elif umur <= 11:
    kategori = "Anak-anak"
elif umur <= 17:
    kategori = "Remaja"
elif umur <= 59:
    kategori = "Dewasa"
else:
    kategori = "Lansia"

print(f"Kategori usia Anda adalah: {kategori}")
# Out:
# Masukkan umur Anda: 70
# Kategori usia Anda adalah: Lansia

# %% [markdown]
# 5. Hitung Tarif Parkir

# %% [markdown]
# 2 Jam Pertama

# %%
jam = int(input("Masukkan lama parkir (jam): "))

if jam <= 2:
    tarif = 5000
elif jam * 2000 + 5000 > 20000:
    tarif = 20000
else:
    tarif = 5000 + (jam - 2) * 2000

print(f"Total tarif parkir: Rp {tarif}")
# Out:
# Masukkan lama parkir (jam): 2
# Total tarif parkir: Rp 5000

# %% [markdown]
# Jam Berikutnya

# %%
jam = int(input("Masukkan lama parkir (jam): "))

if jam <= 2:
    tarif = 5000
elif jam * 2000 + 5000 > 20000:
    tarif = 20000
else:
    tarif = 5000 + (jam - 2) * 2000

print(f"Total tarif parkir: Rp {tarif}")
# Out:
# Masukkan lama parkir (jam): 3
# Total tarif parkir: Rp 7000

# %% [markdown]
# Tarif Maksimal

# %%
jam = int(input("Masukkan lama parkir (jam): "))

if jam <= 2:
    tarif = 5000
elif jam * 2000 + 5000 > 20000:
    tarif = 20000
else:
    tarif = 5000 + (jam - 2) * 2000

print(f"Total tarif parkir: Rp {tarif}")
# Out:
# Masukkan lama parkir (jam): 10
# Total tarif parkir: Rp 20000

# %% [markdown]
# 6. Cek Login Sederhana

# %% [markdown]
# Login berhasil

# %%
username = input("Masukkan username: ")
password = input("Masukkan password: ")

if username == "admin" and password == "1234":
    print("Login berhasil")
else:
    print("Login gagal")
# Out:
# Masukkan username: admin
# Masukkan password: 1234
# Login berhasil

# %% [markdown]
# Login Gagal

# %%
username = input("Masukkan username: ")
password = input("Masukkan password: ")

if username == "admin" and password == "1234":
    print("Login berhasil")
else:
    print("Login gagal")
# Out:
# Masukkan username: admin
# Masukkan password: 5678
# Login gagal

# %% [markdown]
# 7. One Linear If

# %% [markdown]
# Bilangan Genap

# %%
bil = int(input("Masukkan sebuah bilangan: "))
print("Bilangan genap" if bil % 2 == 0 else "Bilangan ganjil")
# Out:
# Masukkan sebuah bilangan: 2
# Bilangan genap

# %% [markdown]
# Bilangan Ganjil

# %%
bil = int(input("Masukkan sebuah bilangan: "))
print("Bilangan genap" if bil % 2 == 0 else "Bilangan ganjil")
# Out:
# Masukkan sebuah bilangan: 3
# Bilangan ganjil

# %% [markdown]
# 8. Menu Restoran dengan Match-Case

# %%
print("===== Menu Restoran =====")
print("1. Nasi Goreng")
print("2. Mie Ayam")
print("3. Soto Ayam")

pilihan = int(input("Masukkan pilihan Anda (1-3): "))

match pilihan:
    case 1:
        print("Menu yang Anda pilih: Nasi Goreng")
    case 2:
        print("Menu yang Anda pilih: Mie Ayam")
    case 3:
        print("Menu yang Anda pilih: Soto Ayam")
    case _:
        print("Menu tidak tersedia")
# Out:
# ===== Menu Restoran =====
# 1. Nasi Goreng
# 2. Mie Ayam
# 3. Soto Ayam
# Masukkan pilihan Anda (1-3): 4
# Menu tidak tersedia

# %% [markdown]
# 9. Studi Kasus Nyata - Program Penentuan Diskon

# %%
barang = input("Masukkan nama barang: ")
harga = float(input("Masukkan harga barang: "))
jumlah = int(input("Masukkan jumlah barang: "))

total = harga * jumlah

if total >= 500000:
    diskon = 0.2
elif total >= 250000:
    diskon = 0.1
else:
    diskon = 0

potongan = total * diskon
bayar = total - potongan

print("\n===== Struk Belanja =====")
print(f"Barang : {barang}")
print(f"Jumlah : {jumlah}")
print(f"Harga  : Rp {harga:.2f}")
print(f"Total  : Rp {total:.2f}")
print(f"Diskon : {diskon * 100}%")
print(f"Bayar  : Rp {bayar:.2f}")
# Out:
# Masukkan nama barang: Motor
# Masukkan harga barang: 30000000
# Masukkan jumlah barang: 4
#
# ===== Struk Belanja =====
# Barang : Motor
# Jumlah : 4
# Harga  : Rp 30000000.00
# Total  : Rp 120000000.00
# Diskon : 20.0%
# Bayar  : Rp 96000000.00
